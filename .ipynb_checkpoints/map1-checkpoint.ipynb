# %%
#country -- italy
import pandas as pandas

locations = pandas.read_csv(r'pleiades-locations-latest.csv')
names = pandas.read_csv(r'pleiades-names-latest.csv')
places = pandas.read_csv(r'pleiades-places-latest.csv')

# %%
import numpy as numpy

# %%
lat_long_boundary = numpy.array([9.77,30.3,12.14,45.4])
locations = locations[(locations.reprLat >= lat_long_boundary[1]) & 
                   (locations.reprLat <= lat_long_boundary[3]) &
                   (locations.reprLong >= lat_long_boundary[0]) &
                   (locations.reprLong <= lat_long_boundary[2])]

# %%
locations.count()
# Out:
# authors              1428
# bbox                 1428
# created              1428
# creators             1428
# currentVersion       1424
# description          1291
# featureType          1428
# geometry             1428
# id                   1428
# locationPrecision    1428
# locationType         1416
# maxDate              1340
# minDate              1340
# modified             1428
# path                 1428
# pid                  1428
# reprLat              1428
# reprLatLong          1428
# reprLong             1428
# tags                   12
# timePeriods          1340
# timePeriodsKeys      1340
# timePeriodsRange     1340
# title                1428
# uid                  1428
# dtype: int64

# %%
locations.head()
# Out:
#          authors                                            bbox  \
# 1     Becker, J.  11.6285463, 42.4193742, 11.6285463, 42.4193742
# 572   Becker, J.  10.3257769, 37.1813894, 10.3257769, 37.1813894
# 1102  Becker, J.  10.6559363, 43.8206237, 10.6559363, 43.8206237
# 1168  Becker, J.            12.0462, 42.05569, 12.0462, 42.05569
# 1684  Becker, J.  11.3476048, 42.6518769, 11.3476048, 42.6518769
#
#                    created creators  currentVersion  \
# 1     2013-07-11T15:48:53Z  jbecker             3.0
# 572   2013-12-12T05:30:57Z  jbecker             1.0
# 1102  2013-07-30T19:17:16Z  jbecker             2.0
# 1168  2018-03-09T00:40:10Z  jbecker             1.0
# 1684  2013-12-01T06:00:57Z  jbecker             4.0
#
#                                             description        featureType  \
# 1     A major urban sanctuary at Vulci with a long p...          temple-2,
# 572                     Location based on OpenStreetMap            island,
# 1102                    Location based on OpenStreetMap            church,
# 1168                                                NaN  settlement-modern
# 1684    Representative location based on OpenStreetMap.             villa,
#
#                                                geometry  \
# 1     {"type": "Point", "coordinates": [11.6285463, ...
# 572   {"type": "Point", "coordinates": [10.3257769, ...
# 1102  {"type": "Point", "coordinates": [10.6559363, ...
# 1168  {"type": "Point", "coordinates": [12.0462, 42....
# 1684  {"type": "Point", "coordinates": [11.3476048, ...
#
#                                             id locationPrecision  ...  \
# 1                    location-of-tempio-grande           precise  ...
# 572                      location-of-ile-plane           precise  ...
# 1102  location-of-san-pietro-a-badia-pozzeveri           precise  ...
# 1168         geonames-location-of-modern-sasso           precise  ...
# 1684                   location-of-roman-villa           precise  ...
#
#                     pid    reprLat            reprLatLong   reprLong tags  \
# 1      /places/48210386  42.419374  42.4193742,11.6285463  11.628546  NaN
# 572      /places/285440  37.181389  37.1813894,10.3257769  10.325777  NaN
# 1102   /places/81533409  43.820624  43.8206237,10.6559363  10.655936  NaN
# 1168  /places/983459813  42.055690       42.05569,12.0462  12.046200  NaN
# 1684  /places/861510570  42.651877  42.6518769,11.3476048  11.347605  NaN
#
#      timePeriods                                 timePeriodsKeys  \
# 1           ACHR  archaic,classical,hellenistic-republican,roman
# 572            M                                          modern
# 1102          MM                      mediaeval-byzantine,modern
# 1168           M                                          modern
# 1684          HR                    hellenistic-republican,roman
#
#      timePeriodsRange                                      title  \
# 1        -750.0,300.0              OSM location of Tempio Grande
# 572     1700.0,2100.0                      location of Île Plane
# 1102     640.0,2100.0   location of San Pietro a Badia Pozzeveri
# 1168    1700.0,2100.0          GeoNames location of modern Sasso
# 1684     -330.0,300.0  OSM location of Villa Romana di Aia Nuova
#
#                                    uid
# 1     b2d62017b95615f275a79666f79a6631
# 572   84fd8f84ed43081b6dc1a29939618526
# 1102  d4674f5790529cd70966cb136a3a7a18
# 1168  c914fd450e7f47088df3d00c4c47b057
# 1684  b3b20b135c9530b91ac33f359b42730c
#
# [5 rows x 25 columns]

# %%
import altair as altair

# %%
#to view the tooltip in the geographic map you have to separate the two maps. 
url_topojson =  'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/italy/italy-regions.json'
topojson_remote = altair.topo_feature(url=url_topojson, feature='ITA_adm1')


base = altair.Chart(topojson_remote).mark_geoshape(
    fill='gray',
    stroke='white'
    #alt.View(strokeWidth=0)
).encode(
).properties( 
   width=800, height=600
)
locations.dropna(inplace=True)
points = altair.Chart(locations).mark_circle(size=100).encode(
    altair.Longitude('reprLong:Q'),
    altair.Latitude('reprLat:Q'),
    color='authors',
    tooltip=['creators', 'description','featureType']
)

legend = altair.Chart(locations).mark_geoshape(
    filled=False,
    strokeWidth=2
).encode(
    altair.Color(
        'authors:N',
        legend=altair.Legend(
            title=None,
            orient='bottom-right',
            offset=0
        )
    )
)



locations.dropna(inplace=True)
barChart = altair.Chart(locations).mark_bar(size=100).encode(
    x='reprLat:Q',
    y='reprLong:Q',
    color='creators:N',
    column='creators:N'

).interactive()

final = base + points + legend
altair.vconcat(final , barChart)
# Out:
# alt.VConcatChart(...)

# %%
# Out:
# alt.Chart(...)
