# %%
#country -- spain

import altair as alt
from vega_datasets import data
import numpy as numpy
import pandas as pandas

# %%
places = pandas.read_csv(r'pleiades-places-latest.csv')

# %%
lat_long_boundary = numpy.array([-7.25,30.38,2.10,60.12])
places = places[(places.reprLat >= lat_long_boundary[1]) & 
                   (places.reprLat <= lat_long_boundary[3]) &
                   (places.reprLong >= lat_long_boundary[0]) &
                   (places.reprLong <= lat_long_boundary[2])]

# %%
places.count()
# Out:
# authors               3896
# bbox                  3896
# connectsWith           749
# created               3896
# creators              3896
# currentVersion        3896
# description           3893
# extent                3896
# featureTypes          3896
# geoContext            3182
# hasConnectionsWith     253
# id                    3896
# locationPrecision     3896
# maxDate               3863
# minDate               3863
# modified              3896
# path                  3896
# reprLat               3896
# reprLatLong           3896
# reprLong              3896
# tags                  2771
# timePeriods           3863
# timePeriodsKeys       3863
# timePeriodsRange      3863
# title                 3896
# uid                   3896
# dtype: int64

# %%
places.dropna(inplace=True)

# %%
places.head()
# Out:
#                                                authors  \
# 80   Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# 105  Spann, P., DARMC, R. Talbert, S. Gillies, J. Å...
# 116  Spann, P., DARMC, B. Kiesling, R. Talbert, R. ...
# 139  Spann, P., B. Kiesling, S. Gillies, J. Åhlfeld...
# 400  Euzennat, M., B. Kiesling, R. Talbert, J. Åhlf...
#
#                                                bbox          connectsWith  \
# 80   -3.7256823, 38.7606439, -3.7256823, 38.7606439         265988,265989
# 105      -0.278608, 39.676219, -0.275887, 39.680031             803793619
# 116        -2.81302, 39.885321, -2.81302, 39.885321  269560,266521,269546
# 139        -4.024491, 39.85668, -4.024491, 39.85668         256463,265847
# 400        -6.11037, 35.198727, -6.11021, 35.199807                275667
#
#                   created     creators  currentVersion  \
# 80   2010-09-24T19:04:44Z   P.O. Spann             9.0
# 105  2010-09-24T19:05:27Z   P.O. Spann             9.0
# 116  2018-06-07T20:36:22Z   P.O. Spann             9.0
# 139  2018-06-08T00:54:33Z   P.O. Spann            11.0
# 400  2018-06-07T22:56:44Z  M. Euzennat             9.0
#
#                                            description  \
# 80   Oretum was a tributary city of the Oretani tha...
# 105  An ancient place, cited: BAtlas 27 E2 Saguntum...
# 116                 Segobriga was an Ibero-Roman city.
# 139  Ancient Toletum, located on the Tagus river, w...
# 400  Lixus was an ancient settlement of Mauretania ...
#
#                                                 extent featureTypes  \
# 80   {"type": "Point", "coordinates": [-3.7256823, ...   settlement
# 105  {"type": "LineString", "coordinates": [[-0.278...   settlement
# 116  {"type": "Point", "coordinates": [-2.81302, 39...   settlement
# 139  {"type": "Point", "coordinates": [-4.024491, 3...   settlement
# 400  {"type": "LineString", "coordinates": [[-6.110...   settlement
#
#                                           geoContext  ...            path  \
# 80   Nuestra Señora de Zúqueca, 2 miles SE Granátula  ...  /places/265990
# 105                                          Sagunto  ...  /places/266021
# 116   Cerro de Cabeza del Griego, 2 miles S Saelices  ...  /places/266036
# 139                                           Toledo  ...  /places/266066
# 400                                       Tchemmisch  ...  /places/275666
#
#        reprLat            reprLatLong  reprLong  \
# 80   38.760644  38.7606439,-3.7256823 -3.725682
# 105  39.678125   39.678125,-0.2772475 -0.277247
# 116  39.885321     39.885321,-2.81302 -2.813020
# 139  39.856680     39.85668,-4.024491 -4.024491
# 400  35.199807     35.199807,-6.11021 -6.110210
#
#                                                   tags timePeriods  \
# 80   dare:ancient=1, dare:feature=settlement, dare:...        HHRL
# 105  dare:ancient=1, dare:major=1, dare:feature=maj...        CHRL
# 116  dare:ancient=1, dare:feature=settlement, dare:...        HRLM
# 139  dare:ancient=1, dare:major=1, dare:feature=maj...       HRLMM
# 400  dare:ancient=1, dare:major=1, dare:feature=maj...       ACHRL
#
#                                        timePeriodsKeys  timePeriodsRange  \
# 80   hellenistic-republican,hellenistic-roman-early...      -330.0,640.0
# 105  classical,hellenistic-republican,roman,late-an...      -550.0,640.0
# 116   hellenistic-republican,roman,late-antique,modern     -330.0,2100.0
# 139  hellenistic-republican,roman,late-antique,medi...     -330.0,2100.0
# 400  archaic,classical,hellenistic-republican,roman...      -750.0,640.0
#
#              title                               uid
# 80          Oretum  5457de9a660d91ed52ab437df93e718e
# 105  Saguntum/Arse  f0ed8f214297bbd28207253e78c340d1
# 116      Segobriga  40632a5bed3d13894c89bbd422a6651c
# 139        Toletum  c5b1f2f8c20e55d9d6442c48a8ad811e
# 400          Lixus  a34f1cdb7047556e232247e3348b99e8
#
# [5 rows x 26 columns]

# %%
#to view the tooltip on the geomap you have to separate it from the rest of the other maps 
url_topojson = 'https://raw.githubusercontent.com/deldersveld/topojson/master/countries/spain/spain-province.json'
topojson_remote = alt.topo_feature(url=url_topojson, feature='ESP_adm2')

base = alt.Chart(topojson_remote).mark_geoshape(
    fill='gray',
    stroke='white'
).encode(
).properties( 
   width=800, height=500
)

points = alt.Chart(places).mark_circle(size=90).encode(
    x='reprLat:Q',
    y='reprLong:Q',
    color='authors:N',
    tooltip=['creators:N', 'description:N','featureType:N']
)
histogram = alt.Chart(places).mark_bar().encode(
    alt.X('reprLat:Q', bin=True),
    y='reprLong:Q',
    color='title:N',
    tooltip=['creators:N', 'description:N','featureType:N','title:N']
).interactive()

bubble_chart = alt.Chart(places).mark_circle().encode(
    alt.X('reprLat:Q', bin=True),
    alt.Y('reprLong:Q', bin=True),
    size='count()',
    color='title:N',
    tooltip=['creators:N', 'description:N','featureType:N','title:N']
).interactive()


final = base + points

# %%
alt.vconcat(final, histogram, bubble_chart)
# Out:
# alt.VConcatChart(...)
